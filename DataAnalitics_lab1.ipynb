# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import wget
#wget.download("https://raw.githubusercontent.com/KAIR-ISZ/public_lectures/master/Data Analytics/Lab 1 - Python review/Data1.csv")
# Out:
# 100% [............................................................................] 139800 / 139800
# 'Data1 (1).csv'

# %%
data = pd.read_csv('Data1.csv', index_col=0)

data.head(10)
# Out:
#              theta_1   theta_2   theta_3   theta_4   theta_5   theta_6
# 2017-01-01  0.756936 -1.467790  0.096136 -0.115306 -0.447908  0.902579
# 2017-01-02  0.767089  0.185797 -1.428536 -0.086443 -0.954288  1.930909
# 2017-01-03  0.404544  1.415887  0.443466  0.000200 -0.892351  2.449691
# 2017-01-04  1.313957 -1.804471 -0.836986  0.011785 -1.012518  1.182085
# 2017-01-05  0.209862  1.315868  0.140993 -0.046473 -1.417092  1.742433
# 2017-01-06 -0.671767 -1.554742  2.933988  0.007891 -0.672258  0.562830
# 2017-01-07 -0.959496  3.023571 -0.856280 -0.001144 -1.229958 -0.187138
# 2017-01-08 -0.191306 -3.130415 -0.256385  0.078293 -0.725807  0.785517
# 2017-01-09 -0.377351 -2.506434 -0.291662 -0.032130 -0.768863 -1.657719
# 2017-01-10  1.091997  1.006235  3.540325  0.012692 -0.662433  0.088907

# %%
sns.lineplot
# Out:
# <function seaborn.relational.lineplot(x=None, y=None, hue=None, size=None, style=None, data=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, dashes=True, markers=None, style_order=None, units=None, estimator='mean', ci=95, n_boot=1000, sort=True, err_style='band', err_kws=None, legend='brief', ax=None, **kwargs)>

# %%
sns.lineplot(data=data)

# %%
data_melted = pd.melt(data, value_vars = data.columns)
data_melted.head(5)
# Out:
#   variable     value
# 0  theta_1  0.756936
# 1  theta_1  0.767089
# 2  theta_1  0.404544
# 3  theta_1  1.313957
# 4  theta_1  0.209862

# %%
sns.set(style="darkgrid")

g = sns.FacetGrid(data = data_melted,  col = "variable",col_wrap = 3, sharex = False)
#bins = np.arange( plt.hist
g = g.map(plt.hist, "value")

# %%
sns.set(style="darkgrid")

g = sns.FacetGrid(data = data_melted,  col = "variable",col_wrap = 3, sharex = False)
#bins = np.arange( plt.hist
g = g.map(sns.kdeplot, "value")

# %%
data_less=data.drop(columns=['theta_5', 'theta_6'])
data_less.head()
# Out:
#              theta_1   theta_2   theta_3   theta_4
# 2017-01-01  0.756936 -1.467790  0.096136 -0.115306
# 2017-01-02  0.767089  0.185797 -1.428536 -0.086443
# 2017-01-03  0.404544  1.415887  0.443466  0.000200
# 2017-01-04  1.313957 -1.804471 -0.836986  0.011785
# 2017-01-05  0.209862  1.315868  0.140993 -0.046473

# %%
data_less.index = pd.to_datetime(data_less.index)
data_less[data_less.index.year == 2018]
# Out:
#              theta_1   theta_2   theta_3   theta_4
# 2018-01-01  0.682693 -3.091767 -0.475717 -0.238530
# 2018-01-02 -0.283107 -0.979955  1.233933  0.158031
# 2018-01-03  1.572221 -2.033528  2.196317  0.041347
# 2018-01-04 -1.042981  0.651530  1.060125  0.064832
# 2018-01-05 -1.392614 -2.570905 -0.600063 -0.015025
# ...              ...       ...       ...       ...
# 2018-12-27  0.473556 -0.651265 -0.523058  0.076798
# 2018-12-28  1.433117  0.325632  0.905920  0.028891
# 2018-12-29  0.285428 -0.476290  1.082404  0.111482
# 2018-12-30  2.249273 -1.233575 -0.666277 -0.080878
# 2018-12-31  0.316409  5.673544 -0.964592 -0.150844
#
# [365 rows x 4 columns]

# %%
sns.lineplot(data=data_less)
# Out:
# C:\Users\agach\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
data_melted_less = pd.melt(data_less, value_vars = data_less.columns)

# %%
g = sns.FacetGrid(data = data_melted_less,  col = "variable",col_wrap = 2, sharex = False)
#bins = np.arange( plt.hist
g = g.map(plt.hist, "value")

# %%
g = sns.FacetGrid(data = data_melted_less,  col = "variable",col_wrap = 2, sharex = False)
#bins = np.arange( plt.hist
g = g.map(sns.kdeplot, "value")
